# %%
import sys
import os

root_dir = os.path.abspath('..')

if root_dir not in sys.path:
    sys.path.append(root_dir)

# %%
import numpy as np
import pandas as pd
from database.db_config import db_connect

# %%
conn = db_connect()
try:
    df = pd.read_sql_query(
        "SELECT * FROM customers",
        conn
    )
finally:
    conn.close()
# Out:
# Database connected successfully
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_23392\3902551850.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(

# %%
print(df.head(), "\nShape :", df.shape)
# Out:
#   customer_id  tenure  monthly_charges            plan tech_support churn
# 0   CUST-1001    12.0            55.50  Month-to-month          Yes    No
# 1   CUST-1002     2.0            70.00  Month-to-month           No   Yes
# 2   CUST-1003     NaN            89.99        One year          Yes    No
# 3   CUST-1004    24.0           105.50        Two year           No    No
# 4   CUST-1005     1.0              NaN  Month-to-month           No   Yes
# Shape : (7, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      7 non-null      str
#  1   tenure           6 non-null      float64
#  2   monthly_charges  6 non-null      float64
#  3   plan             7 non-null      str
#  4   tech_support     7 non-null      str
#  5   churn            7 non-null      str
# dtypes: float64(2), str(4)
# memory usage: 468.0 bytes

# %%
df.isna()
# Out:
#    customer_id  tenure  monthly_charges   plan  tech_support  churn
# 0        False   False            False  False         False  False
# 1        False   False            False  False         False  False
# 2        False    True            False  False         False  False
# 3        False   False            False  False         False  False
# 4        False   False             True  False         False  False
# 5        False   False            False  False         False  False
# 6        False   False            False  False         False  False

# %%
df.isna().sum()
# Out:
# customer_id        0
# tenure             1
# monthly_charges    1
# plan               0
# tech_support       0
# churn              0
# dtype: int64

# %%
len(df)
# Out:
# 7

# %%
df.isna().sum() / len(df) * 100
# Out:
# customer_id         0.000000
# tenure             14.285714
# monthly_charges    14.285714
# plan                0.000000
# tech_support        0.000000
# churn               0.000000
# dtype: float64

# %%
df.describe()
# Out:
#           tenure  monthly_charges
# count   6.000000         6.000000
# mean   19.333333        80.206667
# std    27.171063        27.991450
# min     1.000000        45.000000
# 25%     2.750000        59.125000
# 50%     8.500000        79.995000
# 75%    21.000000       101.622500
# max    72.000000       115.250000

# %%
df["plan"].value_counts()
# Out:
# plan
# Month-to-month    4
# Two year          2
# One year          1
# Name: count, dtype: int64

# %%
df["tech_support"].value_counts()
# Out:
# tech_support
# No     4
# Yes    3
# Name: count, dtype: int64

# %%
df["churn"].value_counts()
# Out:
# churn
# No     4
# Yes    3
# Name: count, dtype: int64
